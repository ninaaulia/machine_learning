# %% [markdown]
# # Classification Model : Breast Cancer Wisconsin (Diagnostic)

# %% [markdown]
# ### import library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler

from sklearn.decomposition import PCA
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, accuracy_score, recall_score

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### load cancer dataset

# %%
df = pd.read_csv('cancer.csv')
df.head(5)
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
display(df.info())
display(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.drop(df[['id', 'Unnamed: 32']], axis = 1 , inplace=True)
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %% [markdown]
# ### EDA

# %%
# dependent variable
sns.countplot(x = df['diagnosis'], data=df, palette = 'Dark2')
plt.show()

# %%
# correlation
sns.set_theme(style="white")
plt.figure(figsize = (30,15))
corr = df.corr()
sns.heatmap(corr, square=True, annot=True)

# %%
#independent variables
sns.pairplot(df, vars = ['radius_mean', 'texture_mean', 'area_mean'], hue="diagnosis")

# %%
#  Boxplot for checking the outliers
plot = [ 'radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst']

a = 5  # number of rows
b = 6  # number of columns
c = 1  # initialize plot counter

fig = plt.figure(figsize=(20,15))

for i in plot:
    plt.subplot(a, b, c)
    plt.title('{}, subplot: {}{}{}'.format(i, a, b, c))
    plt.xlabel(i)
    sns.boxplot(df[i])
    c = c + 1

# %%
# encoding target variable
df["diagnosis"] = df["diagnosis"].replace("M",1)
df["diagnosis"] = df["diagnosis"].replace("B",0)

# %%
X = df.drop(['diagnosis'], axis = 1)
y= df['diagnosis']

SEED = 42
#splitting dataset
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2, random_state = SEED)
X_train.shape, X_test.shape
# Out:
# ((455, 30), (114, 30))

# %% [markdown]
# ### Scaling

# %%
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_test = scale.transform(X_test)

# %% [markdown]
# ### PCA for dimensionality reduction

# %%
# applying pca with n_components = 30

pca = PCA(n_components = 30)
pca.fit(X_train)

sns.set(style='whitegrid')
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('n_components')
plt.ylabel('cumulative explained variance')
plt.show()

# %% [markdown]
# *after 10 n_components pca can't get much variance*

# %%
# 'explained_variance_ratio' is a float type array, which contains variance ratios for each principal component.

evr = pca.explained_variance_ratio_
print(evr)
# Out:
# [4.35027816e-01 1.95000069e-01 9.78151887e-02 6.48640944e-02
#  5.25337760e-02 4.11279962e-02 2.23559034e-02 1.64795219e-02
#  1.38005190e-02 1.20526216e-02 1.05656532e-02 8.83487978e-03
#  7.72384348e-03 5.31689053e-03 2.90035907e-03 2.74863963e-03
#  2.02120554e-03 1.81312048e-03 1.63703163e-03 1.03921453e-03
#  9.98523858e-04 8.78835623e-04 8.09819261e-04 5.76666950e-04
#  4.96295906e-04 2.76290404e-04 2.25813282e-04 5.07660981e-05
#  2.45885848e-05 4.05623540e-06]

# %%
pca = PCA(n_components=10)
pca.fit(X_train)

X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)

# %% [markdown]
# ### decision tree

# %%
SEED = 42

dt = DecisionTreeClassifier(random_state = SEED)
dt.fit(X_train_pca, y_train)

y_pred = dt.predict(X_test_pca)
cm = confusion_matrix(y_test, y_pred)

print(cm)
print('Accuracy Score', accuracy_score(y_test, y_pred))
print('Recall score', recall_score(y_test, y_pred))
# Out:
# [[68  3]
#  [ 3 40]]
# Accuracy Score 0.9473684210526315
# Recall score 0.9302325581395349

# %% [markdown]
# ### Hyperparameter tuning with 5 cross-fold validation

# %%
from sklearn.model_selection import GridSearchCV

dt = DecisionTreeClassifier()

param_dist = {'max_depth': [2,3,4,5,6,7,8,10,12],
              'max_features': [2,3,4,5,6,7,8,9],
              'min_samples_leaf' : [2,3,4,5,6,8,10],
              'criterion' : ['gini', 'entropy']}

dt_cv = GridSearchCV(dt, param_dist, cv = 5)
dt_cv.fit(X_train_pca,y_train)

# Print the tuned parameters and score
print("Tuned Decision Tree Parameters: {}".format(dt_cv.best_params_))
print("Best score is {}".format(dt_cv.best_score_))
# Out:
# Tuned Decision Tree Parameters: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 7, 'min_samples_leaf': 4}
# Best score is 0.9428571428571428

# %%
dt = DecisionTreeClassifier(min_samples_leaf = 4, max_features = 7, max_depth = 6, criterion = 'entropy')
dt.fit(X_train_pca, y_train)

y_pred = dt.predict(X_test_pca)
cm = confusion_matrix(y_test, y_pred)

print(cm)
print('Accuracy Score', accuracy_score(y_test, y_pred))
print('Recall score', recall_score(y_test, y_pred))
# Out:
# [[68  3]
#  [ 2 41]]
# Accuracy Score 0.956140350877193
# Recall score 0.9534883720930233

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(dt,
                   feature_names=X.columns,
                   class_names=['Malignant', 'Benign'],
                   filled=True)

plt.savefig('decision_tree.png')
